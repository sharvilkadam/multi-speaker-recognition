# %%
# Import required libraries
# Add whatever you want
import tensorflow as tf
import numpy as np
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# Test tensorflow
print('TensorFlow version: ' + tf.__version__)
a = tf.constant(2.0)
b = tf.constant(3.0)
c = a * b

sess = tf.Session()
result = sess.run([a, b, c])
print('%f * %f = %f' % (result[0], result[1], result[2]))
sess.close()

# load data
TRAIN_FOLDER = '../data/normalized/train'
TEST_FOLDER = '../data/normalized/test'
ID_FILE = '../data/normalized/id.json'
NUM_SPEAKERS = 200

def get_attributes(fname):
    attr = fname.split('.')[0].split('-')
    dialect = attr[0]
    gender = attr[1][0]
    speaker_id = attr[1]
    sentence_type = attr[2][:2]
    return dialect, gender, speaker_id, sentence_type

def load_files(train):
    X = []
    Y = []
    for speaker_id, flist in train.items():
        for fname in flist:
            filedata = np.load(fname)
            for segment in filedata:
                for x in segment:
                    X.append(x) # dim(x) => (390,)
                    Y.append(speaker_id)
    return np.array(X).astype(np.float32), np.array(Y)
    

def load_train_data():
    import json
    with open(ID_FILE, 'r') as f_json:
        ids = json.load(f_json)
    print('ids', ids)
    
    
    files = [f for f in os.listdir(TRAIN_FOLDER) if os.path.isfile(os.path.join(TRAIN_FOLDER, f))]

    # split train val data
    train = {}
    val = {}
    
    added = {}
    for file in files:
        dialect, gender, speaker_id, sentence_type = get_attributes(file)
        file_path = os.path.join(TRAIN_FOLDER, file)
        if speaker_id not in ids:
            print('ERROR:', speaker_id, 'not found in ids')
        speaker_id = ids[speaker_id]
        val_set = added.setdefault(speaker_id, {})
        if sentence_type not in val_set:
            val.setdefault(speaker_id, []).append(file_path)
            val_set[sentence_type] = True
        else:
            train.setdefault(speaker_id, []).append(file_path)
    # test data    
    test = {}
    files = [f for f in os.listdir(TEST_FOLDER) if os.path.isfile(os.path.join(TEST_FOLDER, f))]
    for file in files:
        dialect, gender, speaker_id, sentence_type = get_attributes(file)
        file_path = os.path.join(TEST_FOLDER, file)
        if speaker_id not in ids:
            print('ERROR:', speaker_id, 'not found in ids')
        speaker_id = ids[speaker_id]
        test.setdefault(speaker_id, []).append(file_path)
    
    # load data
    # input_path = os.path.join(TRAIN_FOLDER, file)
    X_train, Y_train = load_files(train)
    X_val, Y_val = load_files(val)
    X_test, Y_test = load_files(test)
    return X_train, Y_train, X_val, Y_val, X_test, Y_test
    
print('Loading data...')
X_train, Y_train, X_val, Y_val, X_test, Y_test = load_train_data()

print()
print('# Train :', len(Y_train))
print('# Eval  :', len(Y_val))
print('# Test  :', len(Y_test))
print()
# Out:
# TensorFlow version: 1.3.1
# 2.000000 * 3.000000 = 6.000000
# Loading data...
# ids {'MJDG0': 111, 'MDPB0': 60, 'MJRP0': 136, 'MEWM0': 78, 'MILB0': 103, 'MDWD0': 67, 'MJAI0': 106, 'MDLR0': 56, 'MJMA0': 125, 'MDLC2': 53, 'MKLR0': 151, 'MMWS0': 184, 'MJJB0': 119, 'MKAG0': 143, 'MARW0': 11, 'MCEW0': 28, 'MDSS0': 64, 'MAEO0': 4, 'MMDM1': 170, 'MKLS1': 152, 'MDSS1': 65, 'MJBG0': 107, 'MMDS0': 171, 'MFMC0': 80, 'MJJJ0': 120, 'MBOM0': 20, 'MPFU0': 191, 'MJAE0': 105, 'MDLC0': 51, 'MJJM0': 121, 'MJKR0': 122, 'MMWS1': 185, 'MFER0': 79, 'MDAS0': 38, 'MFRM0': 81, 'MEDR0': 71, 'MDLH0': 54, 'MGES0': 90, 'MCTH0': 35, 'MJWT0': 140, 'MGAR0': 88, 'MFXS0': 83, 'MHJB0': 98, 'MJWG0': 138, 'MHRM0': 101, 'MCSS0': 34, 'MCDD0': 25, 'MJEB0': 113, 'MDWM0': 69, 'MJDE0': 110, 'MKJO0': 150, 'MPPC0': 196, 'MJXL0': 142, 'MMEB0': 173, 'MDSJ0': 63, 'MDDC0': 43, 'MKAJ0': 145, 'MAJP0': 6, 'MBMA1': 18, 'MDTB0': 66, 'MJPG0': 128, 'MDLM0': 55, 'MDLB0': 50, 'MMAG0': 163, 'MDEF0': 45, 'MPGH0': 192, 'MDBP0': 40, 'MDEM0': 46, 'MCLK0': 30, 'MMBS0': 165, 'MCHL0': 29, 'MDLC1': 52, 'MLJC0': 158, 'MJRH0': 133, 'MKES0': 149, 'MJEB1': 114, 'MJAC0': 104, 'MJPM0': 129, 'MCPM0': 32, 'MDHL0': 47, 'MCAE0': 22, 'MMEA0': 172, 'MPRK0': 199, 'MMCC0': 166, 'MJLS0': 124, 'MEAL0': 70, 'MKRG0': 154, 'MJMM0': 127, 'MBGT0': 15, 'MKLW0': 153, 'MAFM0': 5, 'MDMA0': 57, 'MJRA0': 131, 'MJDC0': 109, 'MCEF0': 27, 'MEGJ0': 73, 'MHMR0': 100, 'MMDB0': 167, 'MJRG0': 132, 'MMDG0': 168, 'MGXP0': 95, 'MBBR0': 12, 'MGAK0': 87, 'MCDC0': 24, 'MMGC0': 174, 'MJXA0': 141, 'MHXL0': 102, 'MBCG0': 13, 'MDCM0': 42, 'MHBS0': 96, 'MGSH0': 93, 'MCDR0': 26, 'MESJ0': 77, 'MARC0': 10, 'MFWK0': 82, 'MMLM0': 178, 'MMDM0': 169, 'MLSH0': 161, 'MGAG0': 86, 'MPGR0': 193, 'MDBB1': 39, 'MGRP0': 92, 'MEJS0': 75, 'MJRK0': 135, 'MGAW0': 89, 'MEFG0': 72, 'MBMA0': 17, 'MPEB0': 190, 'MDPS0': 61, 'MDNS0': 59, 'MGAF0': 85, 'MJEE0': 115, 'MKAM0': 146, 'MDCD0': 41, 'MDED0': 44, 'MLEL0': 157, 'MFXV0': 84, 'MAPV0': 9, 'MJMD0': 126, 'MMXS0': 186, 'MKAH0': 144, 'MBJV0': 16, 'MMJB1': 177, 'MJHI0': 118, 'MCRE0': 33, 'MMVP0': 182, 'MJDA0': 108, 'MPGR1': 194, 'MCTM0': 36, 'MCLM0': 31, 'MDRD0': 62, 'MMAA0': 162, 'MPMB0': 195, 'MHMG0': 99, 'MGSL0': 94, 'MHIT0': 97, 'MMSM0': 181, 'MAEB0': 3, 'MDMT0': 58, 'MJWS0': 139, 'MPAR0': 189, 'MJLB0': 123, 'MPRB0': 197, 'MESG0': 76, 'MKXL0': 155, 'MDJM0': 48, 'MMPM0': 179, 'MJDM0': 112, 'MCAL0': 23, 'MAKR0': 8, 'MJFH0': 116, 'MKDB0': 147, 'MLJH0': 159, 'MGRL0': 91, 'MMWB0': 183, 'MDKS0': 49, 'MAKB0': 7, 'MCXM0': 37, 'MADD0': 2, 'MJFR0': 117, 'MKDD0': 148, 'MADC0': 1, 'MEJL0': 74, 'MPRD0': 198, 'MMRP0': 180, 'MBML0': 19, 'MMGK0': 176, 'MNET0': 187, 'MMGG0': 175, 'MLBC0': 156, 'MMAM0': 164, 'MJRH1': 134, 'MDWH0': 68, 'MBSB0': 21, 'MABC0': 0, 'MNTW0': 188, 'MBEF0': 14, 'MLNS0': 160, 'MJSR0': 137, 'MJPM1': 130}
#
# # Train : 66325
# # Eval  : 22882
# # Test  : 23212

# %%
input_nodes = 390
hidden_nodes = 200
output_nodes = NUM_SPEAKERS
batch_size = 128
beta = 0.0001 # lambda for regularization

graph = tf.Graph()
with graph.as_default():

    # Input data. For the training data, we use a placeholder that will be fed
    # at run time with a training minibatch.
    tf_train_dataset = tf.placeholder(tf.float32, [None, 390])
    labels = tf.placeholder(tf.int64, [None])
    tf_train_labels = tf.one_hot(labels, output_nodes)
    tf_valid_dataset = tf.constant(X_val)
    tf_test_dataset = tf.constant(X_test)

    # Variables.
    weights_1 = tf.Variable(tf.truncated_normal([input_nodes, hidden_nodes]))
    biases_1 = tf.Variable(tf.zeros([hidden_nodes]))
    weights_2 = tf.Variable(tf.truncated_normal([hidden_nodes, output_nodes]))
    biases_2 = tf.Variable(tf.zeros([output_nodes]))

    # Training computation.
    logits_1 = tf.matmul(tf_train_dataset, weights_1) + biases_1
    sigmoid_layer = tf.nn.sigmoid(logits_1)
    logits_2 = tf.matmul(sigmoid_layer, weights_2) + biases_2
    # Normal loss function
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits_2, labels=tf_train_labels))
    # Loss function with L2 Regularization with beta=0.01
    regularizers = tf.nn.l2_loss(weights_1) + tf.nn.l2_loss(weights_2)
    loss = tf.reduce_mean(loss + beta * regularizers)

    # Optimizer.
    global_step = tf.Variable(0, trainable=False)
    starter_learning_rate = 1e-4

    # tf.train.exponential_decay(learning_rate, global_step, decay_steps, 
    # decay_rate, staircase=False, name=None)
    # staircase: Boolean. If True decay the learning rate at discrete intervals

    # decay every 500 steps with a base of 0.96
    learning_rate = tf.train.exponential_decay(starter_learning_rate,
                                                    global_step, 500, 0.96,
                                                    staircase=True)

    # Passing global_step to minimize() will increment it at each step.
    optimizer = tf.train.AdamOptimizer(learning_rate).minimize(loss, global_step=global_step)

    # Predictions for the training
    train_prediction = tf.nn.softmax(logits_2)
    
    # Predictions for validation 
    logits_1 = tf.matmul(tf_valid_dataset, weights_1) + biases_1
    sigmoid_layer = tf.nn.sigmoid(logits_1)
    logits_2 = tf.matmul(sigmoid_layer, weights_2) + biases_2
    
    valid_prediction = tf.nn.softmax(logits_2)
    
    # Predictions for test
    logits_1 = tf.matmul(tf_test_dataset, weights_1) + biases_1
    sigmoid_layer = tf.nn.sigmoid(logits_1)
    logits_2 = tf.matmul(sigmoid_layer, weights_2) + biases_2
    
    test_prediction =  tf.nn.softmax(logits_2)

# %%
num_epoch = 40
log_step = 50

def accuracy(predictions, labels):
    return (100.0 * np.sum(np.argmax(predictions, 1) == labels)
            / predictions.shape[0])

from sklearn.utils import shuffle
X_train, Y_train = shuffle(X_train, Y_train)

train_dataset = X_train
train_labels = Y_train
valid_labels = Y_val
test_labels = Y_test

curr_step = 0
num_training = len(train_dataset)

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print("Initialized")
    for epoch in range(num_epoch):
        print('===== > train for epoch %d' % epoch)
        for step in range(num_training // batch_size):
            # Pick an offset within the training data, which has been randomized.
            # Note: we could use better randomization across epochs.
            offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
            # Generate a minibatch.
            batch_data = train_dataset[offset:(offset + batch_size), :]
            batch_labels = train_labels[offset:(offset + batch_size)]
            # Prepare a dictionary telling the session where to feed the minibatch.
            # The key of the dictionary is the placeholder node of the graph to be fed,
            # and the value is the numpy array to feed to it.
            feed_dict = {tf_train_dataset : batch_data, labels : batch_labels}
            _, l, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
            curr_step += 1
            if (curr_step % log_step == 0):
                print("Minibatch loss at step {}: {:.4f}".format(curr_step, l))
                print("Minibatch accuracy: {:.1f}".format(accuracy(predictions, batch_labels)))
                print("Validation accuracy: {:.1f}".format(accuracy(valid_prediction.eval(), valid_labels)))
                print()
    print("Test accuracy: {:.1f}".format(accuracy(test_prediction.eval(), test_labels)))
# Out:
# Initialized
# ===== > train for epoch 0
# Minibatch loss at step 49: 473.80255126953125
# Minibatch accuracy: 0.0
# Validation accuracy: 0.4
#
# Minibatch loss at step 99: 468.9704895019531
# Minibatch accuracy: 0.0
# Validation accuracy: 0.4
#
# Minibatch loss at step 149: 463.3742980957031
# Minibatch accuracy: 0.0
# Validation accuracy: 0.4
#
# Minibatch loss at step 199: 459.97003173828125
# Minibatch accuracy: 0.0
# Validation accuracy: 0.5
#
# Minibatch loss at step 249: 454.41021728515625
# Minibatch accuracy: 0.0
# Validation accuracy: 0.5
#
# Minibatch loss at step 299: 449.8601989746094
# Minibatch accuracy: 0.8
# Validation accuracy: 0.5
#
# Minibatch loss at step 349: 445.6317443847656
# Minibatch accuracy: 0.0
# Validation accuracy: 0.5
#
# Minibatch loss at step 399: 441.0968017578125
# Minibatch accuracy: 0.8
# Validation accuracy: 0.5
#
# Minibatch loss at step 449: 439.5332336425781
# Minibatch accuracy: 0.0
# Validation accuracy: 0.5
#
# Minibatch loss at step 499: 433.209228515625
# Minibatch accuracy: 0.8
# Validation accuracy: 0.5
#
# ===== > train for epoch 1
# Minibatch loss at step 31: 430.00750732421875
# Minibatch accuracy: 0.8
# Validation accuracy: 0.5
#
# Minibatch loss at step 81: 426.1251220703125
# Minibatch accuracy: 0.8
# Validation accuracy: 0.5
#
# Minibatch loss at step 131: 421.7493591308594
# Minibatch accuracy: 0.0
# Validation accuracy: 0.5
#
# Minibatch loss at step 181: 418.7657775878906
# Minibatch accuracy: 0.0
# Validation accuracy: 0.6
#
# Minibatch loss at step 231: 415.48516845703125
# Minibatch accuracy: 0.8
# Validation accuracy: 0.6
#
# Minibatch loss at step 281: 411.6359558105469
# Minibatch accuracy: 0.0
# Validation accuracy: 0.6
#
# Minibatch loss at step 331: 408.59552001953125
# Minibatch accuracy: 0.8
# Validation accuracy: 0.6
#
# Minibatch loss at step 381: 404.7237548828125
# Minibatch accuracy: 0.0
# Validation accuracy: 0.6
#
# Minibatch loss at step 431: 400.9064636230469
# Minibatch accuracy: 0.0
# Validation accuracy: 0.6
#
# Minibatch loss at step 481: 396.690673828125
# Minibatch accuracy: 0.0
# Validation accuracy: 0.6
#
# ===== > train for epoch 2
# Minibatch loss at step 13: 394.45806884765625
# Minibatch accuracy: 0.0
# Validation accuracy: 0.6
#
# Minibatch loss at step
# Minibatch accuracy: 0.0
# Validation accuracy: 0.9
#
# Minibatch loss at step 187: 63.00175094604492
# Minibatch accuracy: 2.3
# Validation accuracy: 0.9
#
# Minibatch loss at step 237: 62.736419677734375
# Minibatch accuracy: 1.6
# Validation accuracy: 0.9
#
# Minibatch loss at step 287: 62.606040954589844
# Minibatch accuracy: 0.0
# Validation accuracy: 0.9
#
# Minibatch loss at step 337: 62.328773498535156
# Minibatch accuracy: 0.8
# Validation accuracy: 0.9
#
# Minibatch loss at step 387: 62.159339904785156
# Minibatch accuracy: 0.8
# Validation accuracy: 0.9
#
# Minibatch loss at step 437: 61.94915771484375
# Minibatch accuracy: 0.0
# Validation accuracy: 0.9
#
# Minibatch loss at step 487: 61.75004577636719
# Minibatch accuracy: 1.6
# Validation accuracy: 0.9
#
# ===== > train for epoch 35
# Minibatch loss at step 19: 61.58742904663086
# Minibatch accuracy: 0.8
# Validation accuracy: 0.9
#
# Minibatch loss at step 69: 61.36863708496094
# Minibatch accuracy: 0.8
# Validation accuracy: 1.0
#
# Minibatch loss at step 119: 61.190673828125
# Minibatch accuracy: 0.8
# Validation accuracy: 0.9
#
# Minibatch loss at step 169: 61.011695861816406
# Minibatch accuracy: 0.0
# Validation accuracy: 0.9
#
# Minibatch loss at step 219: 60.78899383544922
# Minibatch accuracy: 0.0
# Validation accuracy: 0.9
#
# Minibatch loss at step 269: 60.66554260253906
# Minibatch accuracy: 0.8
# Validation accuracy: 0.9
#
# Minibatch loss at step 319: 60.38882827758789
# Minibatch accuracy: 0.8
# Validation accuracy: 0.9
#
# Minibatch loss at step 369: 60.21221923828125
# Minibatch accuracy: 2.3
# Validation accuracy: 0.9
#
# Minibatch loss at step 419: 60.02976989746094
# Minibatch accuracy: 0.8
# Validation accuracy: 0.9
#
# Minibatch loss at step 469: 59.845149993896484
# Minibatch accuracy: 0.0
# Validation accuracy: 0.9
#
# ===== > train for epoch 36
# Minibatch loss at step 1: 59.66590118408203
# Minibatch accuracy: 0.8
# Validation accuracy: 0.9
#
# Minibatch loss at step 51: 59.491912841796875
# Minibatch accuracy: 1.6
# Validation accuracy: 0.9
#
# Minibatch loss at step 101: 59.33045196533203
# Minibatch accuracy: 0.8
# Validation accuracy: 0.9
#
# Minibatch loss at step 151: 59.18079376220703
# Minibatch accuracy: 0.8
# Validation accuracy: 0.9
#
# Minibatch loss at step 201: 58.951499938964844
# Minibatch accuracy: 1.6
# Validation accuracy: 0.9
#
# Minibatch loss at step 251: 58.8125114440918
# Minibatch accuracy: 2.3
# Validation accuracy: 0.9
#
# Minibatch loss at step 301: 58.700992584228516
# Minibatch accuracy: 0.8
# Validation accuracy: 0.9
#
# Minibatch loss at step 351: 58.48089599609375
# Minibatch accuracy: 0.8
# Validation accuracy: 0.9
#
# Minibatch loss at step 401: 58.24775314331055
# Minibatch accuracy: 0.0
# Validation accuracy: 0.9
#
# Minibatch loss at step 451: 58.07625961303711
# Minibatch accuracy: 2.3
# Validation accuracy: 0.9
#
# Minibatch loss at step 501: 57.968605041503906
# Minibatch accuracy: 0.8
# Validation accuracy: 0.9
#
# ===== > train for epoch 37
# Minibatch loss at step 33: 57.83163070678711
# Minibatch accuracy: 1.6
# Validation accuracy: 0.9
#
# Minibatch loss at step 83: 57.58876037597656
# Minibatch accuracy: 0.0
# Validation accuracy: 0.9
#
# Minibatch loss at step 133: 57.46731948852539
# Minibatch accuracy: 0.8
# Validation accuracy: 1.0
#
# Minibatch loss at step 183: 57.31586456298828
# Minibatch accuracy: 0.8
# Validation accuracy: 0.9
#
# Minibatch loss at step 233: 57.10874557495117
# Minibatch accuracy: 0.0
# Validation accuracy: 0.9
#
# Minibatch loss at step 283: 56.96202850341797
# Minibatch accuracy: 0.8
# Validation accuracy: 0.9
#
# Minibatch loss at step 333: 56.801456451416016
# Minibatch accuracy: 0.8
# Validation accuracy: 0.9
#
# Minibatch loss at step 383: 56.651893615722656
# Minibatch accuracy: 2.3
# Validation accuracy: 0.9
#
# Minibatch loss at step 433: 56.50082015991211
# Minibatch accuracy: 1.6
# Validation accuracy: 0.9
#
# Minibatch loss at step 483: 56.3340950012207
# Minibatch accuracy: 2.3
# Validation accuracy: 1.0
#
# ===== > train for epoch 38
# Minibatch loss at step 15: 56.16949462890625
# Minibatch accuracy: 0.8
# Validation accuracy: 0.9
#
# Minibatch loss at step 65: 55.97990417480469
# Minibatch accuracy: 0.8
# Validation accuracy: 1.0
#
# Minibatch loss at step 115: 55.8677978515625
# Minibatch accuracy: 0.8
# Validation accuracy: 1.0
#
# Minibatch loss at step 165: 55.74219512939453
# Minibatch accuracy: 1.6
# Validation accuracy: 1.0
#
# Minibatch loss at step 215: 55.523345947265625
# Minibatch accuracy: 3.1
# Validation accuracy: 0.9
#
# Minibatch loss at step 265: 55.379913330078125
# Minibatch accuracy: 0.8
# Validation accuracy: 1.0
#
# Minibatch loss at step 315: 55.25566101074219
# Minibatch accuracy: 0.0
# Validation accuracy: 0.9
#
# Minibatch loss at step 365: 55.114830017089844
# Minibatch accuracy: 0.8
# Validation accuracy: 0.9
#
# Minibatch loss at step 415: 54.955440521240234
# Minibatch accuracy: 1.6
# Validation accuracy: 1.0
#
# Minibatch loss at step 465: 54.825164794921875
# Minibatch accuracy: 0.8
# Validation accuracy: 1.0
#
# Minibatch loss at step 515: 54.669349670410156
# Minibatch accuracy: 0.8
# Validation accuracy: 1.0
#
# ===== > train for epoch 39
# Minibatch loss at step 47: 54.45873260498047
# Minibatch accuracy: 0.0
# Validation accuracy: 1.0
#
# Minibatch loss at step 97: 54.325645446777344
# Minibatch accuracy: 3.1
# Validation accuracy: 1.0
#
# Minibatch loss at step 147: 54.182952880859375
# Minibatch accuracy: 0.0
# Validation accuracy: 1.0
#
# Minibatch loss at step 197: 54.03074264526367
# Minibatch accuracy: 2.3
# Validation accuracy: 1.0
#
# Minibatch loss at step 247: 53.91028594970703
# Minibatch accuracy: 0.8
# Validation accuracy: 1.0
#
# Minibatch loss at step 297: 53.744300842285156
# Minibatch accuracy: 0.8
# Validation accuracy: 1.0
#
# Minibatch loss at step 347: 53.571407318115234
# Minibatch accuracy: 3.1
# Validation accuracy: 0.9
#
# Minibatch loss at step 397: 53.44959259033203
# Minibatch accuracy: 0.8
# Validation accuracy: 1.0
#
# Minibatch loss at step 447: 53.33849334716797
# Minibatch accuracy: 2.3
# Validation accuracy: 1.0
#
# Minibatch loss at step 497: 53.1983642578125
# Minibatch accuracy: 1.6
# Validation accuracy: 1.0
#
# Test accuracy: 1.0
