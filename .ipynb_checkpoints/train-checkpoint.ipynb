# %%
# Import required libraries
# Add whatever you want
import tensorflow as tf
import numpy as np
import os
import scipy.io as spio
import matplotlib.pyplot as plt
# %matplotlib inline

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# Test tensorflow
print('TensorFlow version: ' + tf.__version__)
a = tf.constant(2.0)
b = tf.constant(3.0)
c = a * b

sess = tf.Session()
result = sess.run([a, b, c])
print('%f * %f = %f' % (result[0], result[1], result[2]))
sess.close()

# load data
TRAIN_FOLDER = '../data/normalized/train'
TEST_FOLDER = '../data/normalized/test'
ID_FILE = '../data/normalized/id.json'
NUM_SPEAKERS = 200

def get_attributes(fname):
    attr = fname.split('.')[0].split('-')
    dialect = attr[0]
    gender = attr[1][0]
    speaker_id = attr[1]
    sentence_type = attr[2][:2]
    return dialect, gender, speaker_id, sentence_type

def load_files(train):
    X = []
    Y = []
    for speaker_id, flist in train.items():
        for fname in flist:
            filedata = spio.loadmat(fname)['data'][0, :]
            for segment in filedata:
                for x in segment:
                    X.append(x) # dim(x) => (390,)
                    Y.append(speaker_id)
    return X, Y
    

def load_train_data():
    import json
    with open(ID_FILE, 'r') as f_json:
        ids = json.load(f_json)
    print('ids', ids)
    
    
    files = [f for f in os.listdir(TRAIN_FOLDER) if os.path.isfile(os.path.join(TRAIN_FOLDER, f))]

    # split train val data
    train = {}
    val = {}
    
    added = {}
    for file in files:
        dialect, gender, speaker_id, sentence_type = get_attributes(file)
        file_path = os.path.join(TRAIN_FOLDER, file)
        if speaker_id not in ids:
            print('ERROR:', speaker_id, 'not found in ids')
        speaker_id = ids[speaker_id]
        val_set = added.setdefault(speaker_id, {})
        if sentence_type not in val_set:
            val.setdefault(speaker_id, []).append(file_path)
            val_set[sentence_type] = True
        else:
            train.setdefault(speaker_id, []).append(file_path)
    # test data    
    test = {}
    files = [f for f in os.listdir(TEST_FOLDER) if os.path.isfile(os.path.join(TEST_FOLDER, f))]
    for file in files:
        dialect, gender, speaker_id, sentence_type = get_attributes(file)
        file_path = os.path.join(TEST_FOLDER, file)
        if speaker_id not in ids:
            print('ERROR:', speaker_id, 'not found in ids')
        speaker_id = ids[speaker_id]
        test.setdefault(speaker_id, []).append(file_path)
    
    # load data
    # input_path = os.path.join(TRAIN_FOLDER, file)
    X_train, Y_train = load_files(train)
    X_val, Y_val = load_files(val)
    X_test, Y_test = load_files(test)
    return np.array(X_train), np.array(Y_train), np.array(X_val), np.array(Y_val), np.array(X_test), np.array(Y_test)
    
print('Loading data...')
X_train, Y_train, X_val, Y_val, X_test, Y_test = load_train_data()

print()
print('# Train :', len(Y_train))
print('# Eval  :', len(Y_val))
print('# Test  :', len(Y_test))
print()

# model
def fully_connected(input, num_outputs, act_fn=None):
    return tf.contrib.layers.fully_connected(input, num_outputs,
                                             activation_fn=act_fn,
                                             weights_initializer=tf.random_normal_initializer(0.0, 0.02),
                                             weights_regularizer=tf.contrib.layers.l2_regularizer(scale=0.0001)
                                            )

class BaseModel(object):
    def __init__(self):
        self.batch_size = 128
        self.log_step = 50
        self._build_model()

    def _model(self):
        print('-' * 5 + '  Sample model  ' + '-' * 5)

        print('input layer: ' + str(self.X.get_shape()))

        with tf.variable_scope('fc1'):
            
            self.fc1 = fully_connected(self.X, 390)
            self.relu1 = tf.nn.relu(self.fc1)
            
            print('fc1 layer: ' + str(self.relu1.get_shape()))

        with tf.variable_scope('fc2'):
            
            self.fc2 = fully_connected(self.relu1, 200)
            self.relu2 = tf.nn.relu(self.fc2)
            
            print('fc2 layer: ' + str(self.relu2.get_shape()))
            
        with tf.variable_scope('fc3'):
            
            self.fc3 = fully_connected(self.relu2, 200)
            
            print('fc3 layer: ' + str(self.fc3.get_shape()))
        
        # Return the last layer
        return self.fc3

    def _input_ops(self):
        # Placeholders
        self.X = tf.placeholder(tf.float32, [None, 390])
        self.Y = tf.placeholder(tf.int64, [None])
        
        self.global_step = tf.Variable(0, trainable=False)
        self.starter_learning_rate = 4e-4
        
        # tf.train.exponential_decay(learning_rate, global_step, decay_steps, 
        # decay_rate, staircase=False, name=None)
        # staircase: Boolean. If True decay the learning rate at discrete intervals
        
        # decay every 500 steps with a base of 0.96
        self.learning_rate = tf.train.exponential_decay(self.starter_learning_rate,
                                                        self.global_step, 500, 0.96,
                                                        staircase=True)
        

    def _build_optimizer(self):
        # Adam optimizer 'self.train_op' that minimizes 'self.loss_op'
        
        # Passing global_step to minimize() will increment it at each step.
        optimizer = tf.train.AdamOptimizer(self.learning_rate)
        self.train_op = optimizer.minimize(self.loss_op, global_step=self.global_step)
        
        
    def _loss(self, labels, logits):
        # Softmax cross entropy loss 'self.loss_op'
        
        loss = tf.nn.softmax_cross_entropy_with_logits(labels=labels, logits=logits)
        self.loss_op = tf.reduce_mean(loss)     
        

    def _build_model(self):
        # Define input variables
        self._input_ops()

        # Convert Y to one-hot vector
        labels = tf.one_hot(self.Y, NUM_SPEAKERS)

        # Build a model and get logits
        logits = self._model()

        # Compute loss
        self._loss(labels, logits)
        
        # Build optimizer
        self._build_optimizer()

        # Compute accuracy
        predict = tf.argmax(logits, 1)
        correct = tf.equal(predict, self.Y)
        self.accuracy_op = tf.reduce_mean(tf.cast(correct, tf.float32))
        
    def train(self, sess, X_train, Y_train, X_val, Y_val, num_epoch=40):
        # shuffle
        from sklearn.utils import shuffle
        X_train, Y_train = shuffle(X_train, Y_train)
        
        # try loading checkpoint
        saver = tf.train.Saver()
        save_dir = "tf_models/"        
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        save_path = os.path.join(save_dir, 'csci-599_proj')
        
        try:
            print("Trying to restore last checkpoint ...")

            # Use TensorFlow to find the latest checkpoint - if any.
            last_chk_path = tf.train.latest_checkpoint(checkpoint_dir=save_dir)

            # Try and load the data in the checkpoint.
            saver.restore(sess, save_path=last_chk_path)

            # If we get to this point, the checkpoint was successfully loaded.
            print("Restored checkpoint from:", last_chk_path)
        except:
            # If the above failed for some reason, simply
            # initialize all the variables for the TensorFlow graph.
            print("Failed to restore checkpoint. Initializing variables instead.")
            sess.run(tf.global_variables_initializer())

        step = 0
        losses = []
        accuracies = []
        num_training = len(Y_train)
        print('-' * 5 + '  Start training  ' + '-' * 5)
        for epoch in range(num_epoch):
            print('train for epoch %d' % epoch)
            print('global step: %d' % self.global_step.eval())
            for i in range(num_training // self.batch_size):
                X_ = X_train[i * self.batch_size:(i + 1) * self.batch_size][:]
                Y_ = Y_train[i * self.batch_size:(i + 1) * self.batch_size]
                
                feed_dict = {
                    self.X: X_,
                    self.Y: Y_
                }                
                
                fetches = [self.train_op, self.loss_op, self.accuracy_op]

                _, loss, accuracy = sess.run(fetches, feed_dict=feed_dict)
                losses.append(loss)
                accuracies.append(accuracy)

                if step % self.log_step == 0:
                    print('iteration (%d): loss = %.3f, accuracy = %.3f' %
                        (step, loss, accuracy))
                step += 1
            
            # save state
            model_path = saver.save(sess,
                       save_path=save_path,
                       global_step=self.global_step)
            print("Model saved in %s" % model_path)

            #############################################################################
            # TODO: Plot training curves                                                #
            #############################################################################
            # Graph 1. X: epoch, Y: training loss
            plt.plot(losses)
            plt.title('training loss')
            plt.xlabel('iteration')
            plt.ylabel('loss')
            plt.show()    

            # Graph 2. X: epoch, Y: training accuracy
            plt.plot(accuracies)
            plt.title('training accuracy')
            plt.xlabel('iteration')
            plt.ylabel('accuracy')
            plt.show()

            # Print validation results
            print('validation for epoch %d' % epoch)
            val_accuracy = self.evaluate(sess, X_val, Y_val)
            print('-  epoch %d: validation accuracy = %.3f' % (epoch, val_accuracy))

    def evaluate(self, sess, X_eval, Y_eval):
        eval_accuracy = 0.0
        eval_iter = 0
        for i in range(X_eval.shape[0] // self.batch_size):
            X_ = X_eval[i * self.batch_size:(i + 1) * self.batch_size][:]
            Y_ = Y_eval[i * self.batch_size:(i + 1) * self.batch_size]
                        
            
            feed_dict = {
                    self.X: X_,
                    self.Y: Y_
                }
            
            accuracy = sess.run(self.accuracy_op, feed_dict=feed_dict)
            eval_accuracy += accuracy
            eval_iter += 1
        return eval_accuracy / eval_iter
# Out:
# TensorFlow version: 1.3.1
# 2.000000 * 3.000000 = 6.000000
# Loading data...
# ids {'MRDD0': 147, 'MMGG0': 125, 'MHRM0': 71, 'MFER0': 55, 'MGJC0': 62, 'MWDK0': 196, 'MRWS0': 169, 'MDHS0': 32, 'MDEF0': 29, 'MWAD0': 194, 'MRJT0': 160, 'MDPS0': 42, 'MMAA0': 116, 'MJMD0': 90, 'MRBC0': 144, 'MCPM0': 20, 'MDHL0': 31, 'MRDS0': 148, 'MTRT0': 192, 'MDAC0': 23, 'MCDD0': 14, 'MEDR0': 50, 'MLEL0': 111, 'MADC0': 0, 'MJRH1': 95, 'MGSH0': 65, 'MRMS0': 163, 'MJKR0': 85, 'MMGC0': 124, 'MSFV0': 172, 'MGAG0': 60, 'MMSM0': 129, 'MJDE0': 78, 'MREE0': 149, 'MTPP0': 188, 'MJDA0': 76, 'MBWP0': 11, 'MRAI0': 143, 'MGRP0': 64, 'MDNS0': 40, 'MRGM0': 153, 'MDDC0': 28, 'MKXL0': 109, 'MJHI0': 82, 'MJMM0': 91, 'MMAM0': 118, 'MJEB1': 80, 'MRCG0': 145, 'MAKR0': 3, 'MJEE0': 81, 'MDLB0': 34, 'MTKP0': 184, 'MJDC0': 77, 'MJAC0': 73, 'MPRT0': 139, 'MESG0': 53, 'MJEB0': 79, 'MJLG1': 87, 'MHMR0': 70, 'MMEB0': 123, 'MKLW0': 108, 'MGXP0': 66, 'MDLH0': 37, 'MBJV0': 9, 'MRHL0': 155, 'MTBC0': 179, 'MDMA0': 38, 'MFMC0': 56, 'MPEB0': 132, 'MJJJ0': 84, 'MKAH0': 101, 'MJLB0': 86, 'MRJM1': 159, 'MDBP0': 26, 'MSTF0': 176, 'MNET0': 131, 'MJLS0': 88, 'MDSJ0': 43, 'MPGH0': 133, 'MMDM0': 121, 'MTJG0': 181, 'MTPG0': 187, 'MMGK0': 126, 'MRTJ0': 167, 'MJWT0': 99, 'MDWH0': 48, 'MDJM0': 33, 'MJJB0': 83, 'MEWM0': 54, 'MMDS0': 122, 'MARC0': 5, 'MJXL0': 100, 'MTRR0': 191, 'MARW0': 6, 'MCDC0': 13, 'MKJO0': 105, 'MMRP0': 128, 'MFWK0': 58, 'MLNS0': 114, 'MMXS0': 130, 'MRAB1': 142, 'MLJC0': 112, 'MJSR0': 97, 'MJRH0': 94, 'MCDR0': 15, 'MGAF0': 59, 'MDSS1': 45, 'MDBB1': 25, 'MCEF0': 16, 'MPRD0': 137, 'MILB0': 72, 'MWGR0': 197, 'MRTC0': 166, 'MTQC0': 189, 'MRJM0': 158, 'MRSO0': 164, 'MWAR0': 195, 'MRAB0': 141, 'MTDB0': 180, 'MJAE0': 74, 'MBEF0': 7, 'MSRG0': 175, 'MDLC0': 35, 'MMJB1': 127, 'MPRB0': 136, 'MKLS0': 106, 'MJMA0': 89, 'MAEB0': 1, 'MSMC0': 173, 'MDWM0': 49, 'MCTM0': 22, 'MKLS1': 107, 'MSMS0': 174, 'MRGS0': 154, 'MBGT0': 8, 'MDMT0': 39, 'MEFG0': 51, 'MTLB0': 185, 'MCAL0': 12, 'MZMB0': 199, 'MJPM0': 92, 'MAPV0': 4, 'MDPK0': 41, 'MSAT0': 170, 'MDAS0': 24, 'MLJH0': 113, 'MDWD0': 47, 'MTAS0': 177, 'MRLJ0': 161, 'MMBS0': 120, 'MPGR0': 134, 'MKDT0': 104, 'MRLR0': 162, 'MHJB0': 68, 'MWSB0': 198, 'MSFH0': 171, 'MREH1': 150, 'MHMG0': 69, 'MLBC0': 110, 'MDCD0': 27, 'MRSP0': 165, 'MDTB0': 46, 'MVJH0': 193, 'MRFL0': 152, 'MTRC0': 190, 'MLSH0': 115, 'MPRK0': 138, 'MCHL0': 18, 'MFRM0': 57, 'MJRP0': 96, 'MCSS0': 21, 'MEGJ0': 52, 'MTAT1': 178, 'MRJB1': 156, 'MHIT0': 67, 'MRWA0': 168, 'MCLM0': 19, 'MRJH0': 157, 'MJBG0': 75, 'MMAG0': 117, 'MJPM1': 93, 'MTPF0': 186, 'MDSS0': 44, 'MPPC0': 135, 'MAKB0': 2, 'MBMA0': 10, 'MDEM0': 30, 'MTJS0': 183, 'MMAR0': 119, 'MGRL0': 63, 'MCEW0': 17, 'MRCW0': 146, 'MDLC2': 36, 'MPSW0': 140, 'MKAJ0': 102, 'MRFK0': 151, 'MTJM0': 182, 'MJWS0': 98, 'MKAM0': 103, 'MGES0': 61}
#
# # Train : 72544
# # Eval  : 25285
# # Test  : 28433

# %%
import os
import time
from datetime import datetime

start_time = time.time()
print(datetime.now())
print()

# Clear old computation graphs
tf.reset_default_graph()

# Train our sample model
with tf.Session(config=tf.ConfigProto(
      allow_soft_placement=True)) as sess:
    with tf.device('/gpu:0'):
        model = BaseModel()
        model.train(sess, X_train, Y_train, X_val, Y_val, num_epoch=40)
        accuracy = model.evaluate(sess, X_test, Y_test)
        print('***** test accuracy: %.3f' % accuracy)
        
print('Done')
print(datetime.now())
print("Total time: %s seconds" % (time.time() - start_time))
# Out:
# 2017-11-10 05:21:24.009533
#
# -----  Sample model  -----
# input layer: (?, 390)
# fc1 layer: (?, 390)
# fc2 layer: (?, 200)
# fc3 layer: (?, 200)
# Trying to restore last checkpoint ...
# Failed to restore checkpoint. Initializing variables instead.
# -----  Start training  -----
# train for epoch 0
# global step: 0
# iteration (0): loss = 5.301, accuracy = 0.008
# iteration (50): loss = 5.304, accuracy = 0.000
# iteration (100): loss = 5.278, accuracy = 0.008
# iteration (150): loss = 5.284, accuracy = 0.008
# iteration (200): loss = 5.284, accuracy = 0.000
# iteration (250): loss = 5.309, accuracy = 0.000
# iteration (300): loss = 5.288, accuracy = 0.008
# iteration (350): loss = 5.293, accuracy = 0.008
# iteration (400): loss = 5.265, accuracy = 0.008
# iteration (450): loss = 5.192, accuracy = 0.031
# iteration (500): loss = 5.078, accuracy = 0.000
# iteration (550): loss = 4.974, accuracy = 0.016
# Model saved in tf_models/csci-599_proj-566
# validation for epoch 0
# -  epoch 0: validation accuracy = 0.022
# train for epoch 1
# global step: 566
# iteration (600): loss = 4.893, accuracy = 0.016
# iteration (650): loss = 4.795, accuracy = 0.039
# iteration (700): loss = 4.799, accuracy = 0.031
# iteration (750): loss = 4.751, accuracy = 0.055
# iteration (800): loss = 4.481, accuracy = 0.070
# iteration (850): loss = 4.536, accuracy = 0.031
# iteration (900): loss = 4.590, accuracy = 0.055
# iteration (950): loss = 4.540, accuracy = 0.047
# iteration (1000): loss = 4.398, accuracy = 0.086
# iteration (1050): loss = 4.415, accuracy = 0.047
# iteration (1100): loss = 4.428, accuracy = 0.070
# Model saved in tf_models/csci-599_proj-1132
# validation for epoch 1
# -  epoch 1: validation accuracy = 0.052
# train for epoch 2
# global step: 1132
# iteration (1150): loss = 4.274, accuracy = 0.078
# iteration (1200): loss = 4.593, accuracy = 0.086
# iteration (1250): loss = 4.475, accuracy = 0.078
# iteration (1300): loss = 4.484, accuracy = 0.078
# iteration (1350): loss = 4.244, accuracy = 0.109
# iteration (1400): loss = 4.295, accuracy = 0.070
# iteration (1450): loss = 4.261, accuracy = 0.125
# iteration (1500): loss = 4.370, accuracy = 0.070
# iteration (1550): loss = 4.305, accuracy = 0.102
# iteration (1600): loss = 4.058, accuracy = 0.078
# iteration (1650): loss = 4.008, accuracy = 0.109
# Model saved in tf_models/csci-599_proj-1698
# validation for epoch 2
# -  epoch 2: validation accuracy = 0.078
# train for epoch 3
# global step: 1698
# iteration (1700): loss = 4.142, accuracy = 0.086
# iteration (1750): loss = 4.012, accuracy = 0.102
# iteration (1800): loss = 4.159, accuracy = 0.094
# iteration (1850): loss = 4.033, accuracy = 0.172
# iteration (1900): loss = 4.278, accuracy = 0.102
# iteration (1950): loss = 4.086, accuracy = 0.102
# iteration (2000): loss = 3.993, accuracy = 0.109
# iteration (2050): loss = 3.940, accuracy = 0.125
# iteration (2100): loss = 4.301, accuracy = 0.094
# iteration (2150): loss = 3.820, accuracy = 0.141
# iteration (2200): loss = 4.109, accuracy = 0.141
# iteration (2250): loss = 3.965, accuracy = 0.125
# Model saved in tf_models/csci-599_proj-2264
# validation for epoch 3
# -  epoch 3: validation accuracy = 0.106
# train for epoch 4
# global step: 2264
# iteration (2300): loss = 4.026, accuracy = 0.148
# iteration (2350): loss = 3.831, accuracy = 0.141
# iteration (2400): loss = 3.783, accuracy = 0.133
# iteration (2450): loss = 3.706, accuracy = 0.180
# iteration (2500): loss = 3.632, accuracy = 0.172
# iteration (2550): loss = 3.659, accuracy = 0.172
# iteration (2600): loss = 3.689, accuracy = 0.180
# iteration (2650): loss = 3.586, accuracy = 0.203
# iteration (2700): loss = 3.625, accuracy = 0.172
# iteration (2750): loss = 3.717, accuracy = 0.188
# iteration (2800): loss = 3.416, accuracy = 0.203
# Model saved in tf_models/csci-599_proj-2830
# validation for epoch 4
# -  epoch 4: validation accuracy = 0.129
# train for epoch 5
# global step: 2830
# iteration (2850): loss = 3.784, accuracy = 0.172
# iteration (2900): loss = 3.763, accuracy = 0.172
# iteration (2950): loss = 3.727, accuracy = 0.164
# iteration (3000): loss = 3.565, accuracy = 0.227
# iteration (3050): loss = 3.642, accuracy = 0.195
# iteration (3100): loss = 3.796, accuracy = 0.133
# iteration (3150): loss = 3.708, accuracy = 0.164
# iteration (3200): loss = 3.639, accuracy = 0.180
# iteration (3250): loss = 3.568, accuracy = 0.227
# iteration (3300): loss = 3.373, accuracy = 0.234
# iteration (3350): loss = 3.884, accuracy = 0.117
# Model saved in tf_models/csci-599_proj-3396
# validation for epoch 5
# -  epoch 5: validation accuracy = 0.148
# train for epoch 6
# global step: 3396
# iteration (3400): loss = 3.588, accuracy = 0.188
# iteration (3450): loss = 3.384, accuracy = 0.250
# iteration (3500): loss = 3.262, accuracy = 0.281
# iteration (3550): loss = 3.405, accuracy = 0.188
# iteration (3600): loss = 3.396, accuracy = 0.219
# iteration (3650): loss = 3.292, accuracy = 0.258
# iteration (3700): loss = 3.586, accuracy = 0.156
# iteration (3750): loss = 3.462, accuracy = 0.242
# iteration (3800): loss = 3.492, accuracy = 0.188
# iteration (3850): loss = 3.295, accuracy = 0.227
# iteration (3900): loss = 3.276, accuracy = 0.242
# iteration (3950): loss = 3.262, accuracy = 0.211
# Model saved in tf_models/csci-599_proj-3962
# validation for epoch 6
# -  epoch 6: validation accuracy = 0.165
# train for epoch 7
# global step: 3962
# iteration (4000): loss = 3.499, accuracy = 0.219
# iteration (4050): loss = 3.312, accuracy = 0.227
# iteration (4100): loss = 3.122, accuracy = 0.344
# iteration (4150): loss = 3.112, accuracy = 0.273
# iteration (4200): loss = 3.085, accuracy = 0.227
# iteration (4250): loss = 3.439, accuracy = 0.203
# iteration (4300): loss = 3.236, accuracy = 0.203
# iteration (4350): loss = 3.191, accuracy = 0.281
# iteration (4400): loss = 3.192, accuracy = 0.250
# iteration (4450): loss = 3.228, accuracy = 0.305
# iteration (4500): loss = 3.163, accuracy = 0.289
# Model saved in tf_models/csci-599_proj-4528
# validation for epoch 7
# -  epoch 7: validation accuracy = 0.179
# train for epoch 8
# global step: 4528
# iteration (4550): loss = 3.185, accuracy = 0.250
# iteration (4600): loss = 3.031, accuracy = 0.258
# iteration (4650): loss = 3.098, accuracy = 0.312
# iteration (4700): loss = 3.160, accuracy = 0.273
# iteration (4750): loss = 3.319, accuracy = 0.219
# iteration (4800): loss = 3.118, accuracy = 0.328
# iteration (4850): loss = 3.091, accuracy = 0.273
# iteration (4900): loss = 2.988, accuracy = 0.305
# iteration (4950): loss = 3.230, accuracy = 0.242
# iteration (5000): loss = 2.764, accuracy = 0.297
# iteration (5050): loss = 3.105, accuracy = 0.344
# Model saved in tf_models/csci-599_proj-5094
# validation for epoch 8
# -  epoch 8: validation accuracy = 0.192
# train for epoch 9
# global step: 5094
# iteration (5100): loss = 3.144, accuracy = 0.273
# iteration (5150): loss = 2.883, accuracy = 0.312
# iteration (5200): loss = 3.179, accuracy = 0.234
# iteration (5250): loss = 3.080, accuracy = 0.258
# iteration (5300): loss = 2.926, accuracy = 0.328
# iteration (5350): loss = 3.063, accuracy = 0.305
# iteration (5400): loss = 2.948, accuracy = 0.344
# iteration (5450): loss = 3.071, accuracy = 0.258
# iteration (5500): loss = 2.916, accuracy = 0.305
# iteration (5550): loss = 3.163, accuracy = 0.258
# iteration (5600): loss = 3.023, accuracy = 0.305
# iteration (5650): loss = 2.793, accuracy = 0.281
# Model saved in tf_models/csci-599_proj-5660
# validation for epoch 9
# -  epoch 9: validation accuracy = 0.203
# train for epoch 10
# global step: 5660
# iteration (5700): loss = 2.835, accuracy = 0.344
# iteration (5750): loss = 2.833, accuracy = 0.344
# iteration (5800): loss = 3.106, accuracy = 0.211
# iteration (5850): loss = 2.871, accuracy = 0.312
# iteration (5900): loss = 2.718, accuracy = 0.281
# iteration (5950): loss = 2.929, accuracy = 0.297
# iteration (6000): loss = 2.692, accuracy = 0.336
# iteration (6050): loss = 2.995, accuracy = 0.266
# iteration (6100): loss = 2.855, accuracy = 0.305
# iteration (6150): loss = 2.852, accuracy = 0.352
# iteration (6200): loss = 2.965, accuracy = 0.281
# Model saved in tf_models/csci-599_proj-6226
# validation for epoch 10
# -  epoch 10: validation accuracy = 0.212
# train for epoch 11
# global step: 6226
# iteration (6250): loss = 2.829, accuracy = 0.320
# iteration (6300): loss = 2.667, accuracy = 0.320
# iteration (6350): loss = 2.944, accuracy = 0.305
# iteration (6400): loss = 2.801, accuracy = 0.281
# iteration (6450): loss = 2.950, accuracy = 0.289
# iteration (6500): loss = 2.860, accuracy = 0.320
# iteration (6550): loss = 2.955, accuracy = 0.305
# iteration (6600): loss = 2.616, accuracy = 0.359
# iteration (6650): loss = 2.769, accuracy = 0.281
# iteration (6700): loss = 2.618, accuracy = 0.383
# iteration (6750): loss = 2.695, accuracy = 0.406
# Model saved in tf_models/csci-599_proj-6792
# validation for epoch 11
# -  epoch 11: validation accuracy = 0.222
# train for epoch 12
# global step: 6792
# iteration (6800): loss = 2.729, accuracy = 0.336
# iteration (6850): loss = 2.818, accuracy = 0.344
# iteration (6900): loss = 2.659, accuracy = 0.383
# iteration (6950): loss = 2.661, accuracy = 0.305
# iteration (7000): loss = 2.925, accuracy = 0.312
# iteration (7050): loss = 2.829, accuracy = 0.273
# iteration (7100): loss = 2.761, accuracy = 0.367
# iteration (7150): loss = 2.921, accuracy = 0.320
# iteration (7200): loss = 3.053, accuracy = 0.305
# iteration (7250): loss = 2.484, accuracy = 0.398
# iteration (7300): loss = 2.602, accuracy = 0.328
# iteration (7350): loss = 2.810, accuracy = 0.344
# Model saved in tf_models/csci-599_proj-7358
# validation for epoch 12
# -  epoch 12: validation accuracy = 0.231
# train for epoch 13
# global step: 7358
# iteration (7400): loss = 2.739, accuracy = 0.352
# iteration (7450): loss = 2.700, accuracy = 0.359
# iteration (7500): loss = 2.487, accuracy = 0.406
# iteration (7550): loss = 2.804, accuracy = 0.328
# iteration (7600): loss = 2.758, accuracy = 0.352
# iteration (7650): loss = 2.486, accuracy = 0.430
# iteration (7700): loss = 2.410, accuracy = 0.414
# iteration (7750): loss = 2.559, accuracy = 0.359
# iteration (7800): loss = 2.494, accuracy = 0.445
# iteration (7850): loss = 2.479, accuracy = 0.375
# iteration (7900): loss = 2.416, accuracy = 0.406
# Model saved in tf_models/csci-599_proj-7924
# validation for epoch 13
# -  epoch 13: validation accuracy = 0.238
# train for epoch 14
# global step: 7924
# iteration (7950): loss = 2.575, accuracy = 0.383
# iteration (8000): loss = 2.673, accuracy = 0.359
# iteration (8050): loss = 2.595, accuracy = 0.398
# iteration (8100): loss = 2.800, accuracy = 0.336
# iteration (8150): loss = 2.532, accuracy = 0.352
# iteration (8200): loss = 2.733, accuracy = 0.359
# iteration (8250): loss = 2.384, accuracy = 0.422
# iteration (8300): loss = 2.454, accuracy = 0.391
# iteration (8350): loss = 2.561, accuracy = 0.336
# iteration (8400): loss = 2.470, accuracy = 0.352
# iteration (8450): loss = 2.345, accuracy = 0.453
# Model saved in tf_models/csci-599_proj-8490
# validation for epoch 14
# -  epoch 14: validation accuracy = 0.246
# train for epoch 15
# global step: 8490
# iteration (8500): loss = 2.687, accuracy = 0.320
# iteration (8550): loss = 2.719, accuracy = 0.336
# iteration (8600): loss = 2.322, accuracy = 0.453
# iteration (8650): loss = 2.281, accuracy = 0.414
# iteration (8700): loss = 2.382, accuracy = 0.383
# iteration (8750): loss = 2.487, accuracy = 0.391
# iteration (8800): loss = 2.638, accuracy = 0.344
# iteration (8850): loss = 2.511, accuracy = 0.414
# iteration (8900): loss = 2.483, accuracy = 0.383
# iteration (8950): loss = 2.319, accuracy = 0.406
# iteration (9000): loss = 2.472, accuracy = 0.430
# iteration (9050): loss = 2.677, accuracy = 0.383
# Model saved in tf_models/csci-599_proj-9056
# validation for epoch 15
# -  epoch 15: validation accuracy = 0.253
# train for epoch 16
# global step: 9056
# iteration (9100): loss = 2.482, accuracy = 0.430
# iteration (9150): loss = 2.510, accuracy = 0.398
# iteration (9200): loss = 2.257, accuracy = 0.453
# iteration (9250): loss = 2.188, accuracy = 0.430
# iteration (9300): loss = 2.256, accuracy = 0.414
# iteration (9350): loss = 2.521, accuracy = 0.406
# iteration (9400): loss = 2.504, accuracy = 0.383
# iteration (9450): loss = 2.442, accuracy = 0.375
# iteration (9500): loss = 2.715, accuracy = 0.312
# iteration (9550): loss = 2.491, accuracy = 0.367
# iteration (9600): loss = 2.475, accuracy = 0.359
# Model saved in tf_models/csci-599_proj-9622
# validation for epoch 16
# -  epoch 16: validation accuracy = 0.260
# train for epoch 17
# global step: 9622
# iteration (9650): loss = 2.392, accuracy = 0.398
# iteration (9700): loss = 2.323, accuracy = 0.438
# iteration (9750): loss = 2.639, accuracy = 0.359
# iteration (9800): loss = 2.077, accuracy = 0.477
# iteration (9850): loss = 2.376, accuracy = 0.391
# iteration (9900): loss = 2.340, accuracy = 0.414
# iteration (9950): loss = 2.200, accuracy = 0.453
# iteration (10000): loss = 2.354, accuracy = 0.422
# iteration (10050): loss = 2.293, accuracy = 0.422
# iteration (10100): loss = 1.864, accuracy = 0.477
# iteration (10150): loss = 2.469, accuracy = 0.391
# Model saved in tf_models/csci-599_proj-10188
# validation for epoch 17
# -  epoch 17: validation accuracy = 0.265
# train for epoch 18
# global step: 10188
# iteration (10200): loss = 2.260, accuracy = 0.469
# iteration (10250): loss = 2.204, accuracy = 0.430
# iteration (10300): loss = 2.362, accuracy = 0.391
# iteration (10350): loss = 2.200, accuracy = 0.414
# iteration (10400): loss = 2.284, accuracy = 0.367
# iteration (10450): loss = 2.317, accuracy = 0.445
# iteration (10500): loss = 2.411, accuracy = 0.406
# iteration (10550): loss = 2.253, accuracy = 0.461
# iteration (10600): loss = 2.412, accuracy = 0.414
# iteration (10650): loss = 2.243, accuracy = 0.414
# iteration (10700): loss = 2.489, accuracy = 0.438
# iteration (10750): loss = 2.152, accuracy = 0.398
# Model saved in tf_models/csci-599_proj-10754
# validation for epoch 18
# -  epoch 18: validation accuracy = 0.270
# train for epoch 19
# global step: 10754
# iteration (10800): loss = 2.208, accuracy = 0.453
# iteration (10850): loss = 2.269, accuracy = 0.430
# iteration (10900): loss = 2.655, accuracy = 0.359
# iteration (10950): loss = 2.346, accuracy = 0.367
# iteration (11000): loss = 1.976, accuracy = 0.500
# iteration (11050): loss = 2.472, accuracy = 0.383
# iteration (11100): loss = 2.407, accuracy = 0.469
# iteration (11150): loss = 2.338, accuracy = 0.406
# iteration (11200): loss = 1.962, accuracy = 0.523
# iteration (11250): loss = 2.366, accuracy = 0.352
# iteration (11300): loss = 2.345, accuracy = 0.391
# Model saved in tf_models/csci-599_proj-11320
# validation for epoch 19
# -  epoch 19: validation accuracy = 0.273
# train for epoch 20
# global step: 11320
# iteration (11350): loss = 2.148, accuracy = 0.453
# iteration (11400): loss = 2.097, accuracy = 0.484
# iteration (11450): loss = 2.155, accuracy = 0.453
# iteration (11500): loss = 2.151, accuracy = 0.523
# iteration (11550): loss = 2.325, accuracy = 0.406
# iteration (11600): loss = 2.100, accuracy = 0.445
# iteration (11650): loss = 2.022, accuracy = 0.523
# iteration (11700): loss = 2.412, accuracy = 0.438
# iteration (11750): loss = 2.272, accuracy = 0.438
# iteration (11800): loss = 2.312, accuracy = 0.391
# iteration (11850): loss = 2.108, accuracy = 0.445
# Model saved in tf_models/csci-599_proj-11886
# validation for epoch 20
# -  epoch 20: validation accuracy = 0.277
# train for epoch 21
# global step: 11886
# iteration (11900): loss = 2.628, accuracy = 0.391
# iteration (11950): loss = 1.980, accuracy = 0.500
# iteration (12000): loss = 2.192, accuracy = 0.430
# iteration (12050): loss = 2.085, accuracy = 0.445
# iteration (12100): loss = 2.003, accuracy = 0.477
# iteration (12150): loss = 1.902, accuracy = 0.539
# iteration (12200): loss = 2.100, accuracy = 0.461
# iteration (12250): loss = 2.399, accuracy = 0.422
# iteration (12300): loss = 2.373, accuracy = 0.422
# iteration (12350): loss = 2.286, accuracy = 0.414
# iteration (12400): loss = 2.079, accuracy = 0.531
# iteration (12450): loss = 2.196, accuracy = 0.445
# Model saved in tf_models/csci-599_proj-12452
# validation for epoch 21
# -  epoch 21: validation accuracy = 0.279
# train for epoch 22
# global step: 12452
# iteration (12500): loss = 2.448, accuracy = 0.438
# iteration (12550): loss = 2.062, accuracy = 0.523
# iteration (12600): loss = 2.313, accuracy = 0.414
# iteration (12650): loss = 2.016, accuracy = 0.477
# iteration (12700): loss = 2.219, accuracy = 0.414
# iteration (12750): loss = 2.281, accuracy = 0.398
# iteration (12800): loss = 1.856, accuracy = 0.586
# iteration (12850): loss = 1.963, accuracy = 0.492
# iteration (12900): loss = 2.205, accuracy = 0.477
# iteration (12950): loss = 2.189, accuracy = 0.430
# iteration (13000): loss = 2.363, accuracy = 0.414
# Model saved in tf_models/csci-599_proj-13018
# validation for epoch 22
# -  epoch 22: validation accuracy = 0.283
# train for epoch 23
# global step: 13018
# iteration (13050): loss = 2.228, accuracy = 0.461
# iteration (13100): loss = 2.044, accuracy = 0.492
# iteration (13150): loss = 2.014, accuracy = 0.547
# iteration (13200): loss = 2.071, accuracy = 0.516
# iteration (13250): loss = 2.014, accuracy = 0.562
# iteration (13300): loss = 2.086, accuracy = 0.477
# iteration (13350): loss = 2.036, accuracy = 0.500
# iteration (13400): loss = 2.007, accuracy = 0.508
# iteration (13450): loss = 2.312, accuracy = 0.414
# iteration (13500): loss = 2.147, accuracy = 0.484
# iteration (13550): loss = 2.281, accuracy = 0.469
# Model saved in tf_models/csci-599_proj-13584
# validation for epoch 23
# -  epoch 23: validation accuracy = 0.286
# train for epoch 24
# global step: 13584
# iteration (13600): loss = 2.090, accuracy = 0.461
# iteration (13650): loss = 2.257, accuracy = 0.430
# iteration (13700): loss = 2.142, accuracy = 0.430
# iteration (13750): loss = 2.090, accuracy = 0.484
# iteration (13800): loss = 2.117, accuracy = 0.422
# iteration (13850): loss = 2.083, accuracy = 0.414
# iteration (13900): loss = 2.139, accuracy = 0.422
# iteration (13950): loss = 1.855, accuracy = 0.516
# iteration (14000): loss = 2.295, accuracy = 0.461
# iteration (14050): loss = 2.029, accuracy = 0.500
# iteration (14100): loss = 2.034, accuracy = 0.461
# Model saved in tf_models/csci-599_proj-14150
# validation for epoch 24
# -  epoch 24: validation accuracy = 0.289
# train for epoch 25
# global step: 14150
# iteration (14150): loss = 1.957, accuracy = 0.492
# iteration (14200): loss = 2.008, accuracy = 0.484
# iteration (14250): loss = 1.909, accuracy = 0.516
# iteration (14300): loss = 2.006, accuracy = 0.492
# iteration (14350): loss = 1.887, accuracy = 0.477
# iteration (14400): loss = 2.112, accuracy = 0.430
# iteration (14450): loss = 2.100, accuracy = 0.469
# iteration (14500): loss = 2.106, accuracy = 0.453
# iteration (14550): loss = 1.751, accuracy = 0.531
# iteration (14600): loss = 1.973, accuracy = 0.516
# iteration (14650): loss = 2.233, accuracy = 0.430
# iteration (14700): loss = 2.014, accuracy = 0.516
# Model saved in tf_models/csci-599_proj-14716
# validation for epoch 25
# -  epoch 25: validation accuracy = 0.291
# train for epoch 26
# global step: 14716
# iteration (14750): loss = 2.061, accuracy = 0.516
# iteration (14800): loss = 2.119, accuracy = 0.484
# iteration (14850): loss = 2.019, accuracy = 0.531
# iteration (14900): loss = 2.071, accuracy = 0.477
# iteration (14950): loss = 1.921, accuracy = 0.547
# iteration (15000): loss = 1.776, accuracy = 0.484
# iteration (15050): loss = 1.967, accuracy = 0.469
# iteration (15100): loss = 2.194, accuracy = 0.438
# iteration (15150): loss = 1.955, accuracy = 0.508
# iteration (15200): loss = 1.958, accuracy = 0.508
# iteration (15250): loss = 1.949, accuracy = 0.477
# Model saved in tf_models/csci-599_proj-15282
# validation for epoch 26
# -  epoch 26: validation accuracy = 0.294
# train for epoch 27
# global step: 15282
# iteration (15300): loss = 1.876, accuracy = 0.547
# iteration (15350): loss = 2.081, accuracy = 0.469
# iteration (15400): loss = 2.121, accuracy = 0.516
# iteration (15450): loss = 2.098, accuracy = 0.484
# iteration (15500): loss = 1.706, accuracy = 0.609
# iteration (15550): loss = 1.966, accuracy = 0.516
# iteration (15600): loss = 1.956, accuracy = 0.508
# iteration (15650): loss = 1.946, accuracy = 0.516
# iteration (15700): loss = 1.939, accuracy = 0.523
# iteration (15750): loss = 1.824, accuracy = 0.516
# iteration (15800): loss = 1.759, accuracy = 0.555
# Model saved in tf_models/csci-599_proj-15848
# validation for epoch 27
# -  epoch 27: validation accuracy = 0.296
# train for epoch 28
# global step: 15848
# iteration (15850): loss = 1.936, accuracy = 0.477
# iteration (15900): loss = 1.924, accuracy = 0.531
# iteration (15950): loss = 1.844, accuracy = 0.555
# iteration (16000): loss = 1.941, accuracy = 0.469
# iteration (16050): loss = 2.126, accuracy = 0.430
# iteration (16100): loss = 2.007, accuracy = 0.469
# iteration (16150): loss = 1.958, accuracy = 0.508
# iteration (16200): loss = 1.814, accuracy = 0.523
# iteration (16250): loss = 2.179, accuracy = 0.406
# iteration (16300): loss = 1.902, accuracy = 0.492
# iteration (16350): loss = 2.250, accuracy = 0.477
# iteration (16400): loss = 1.943, accuracy = 0.539
# Model saved in tf_models/csci-599_proj-16414
# validation for epoch 28
# -  epoch 28: validation accuracy = 0.299
# train for epoch 29
# global step: 16414
# iteration (16450): loss = 1.898, accuracy = 0.531
# iteration (16500): loss = 1.593, accuracy = 0.555
# iteration (16550): loss = 2.012, accuracy = 0.477
# iteration (16600): loss = 1.803, accuracy = 0.562
# iteration (16650): loss = 1.819, accuracy = 0.477
# iteration (16700): loss = 1.839, accuracy = 0.547
# iteration (16750): loss = 1.961, accuracy = 0.523
# iteration (16800): loss = 1.773, accuracy = 0.547
# iteration (16850): loss = 1.614, accuracy = 0.539
# iteration (16900): loss = 2.006, accuracy = 0.477
# iteration (16950): loss = 1.557, accuracy = 0.602
# Model saved in tf_models/csci-599_proj-16980
# validation for epoch 29
# -  epoch 29: validation accuracy = 0.301
# train for epoch 30
# global step: 16980
# iteration (17000): loss = 2.184, accuracy = 0.438
# iteration (17050): loss = 2.158, accuracy = 0.461
# iteration (17100): loss = 1.933, accuracy = 0.430
# iteration (17150): loss = 1.833, accuracy = 0.555
# iteration (17200): loss = 1.818, accuracy = 0.531
# iteration (17250): loss = 1.829, accuracy = 0.508
# iteration (17300): loss = 2.022, accuracy = 0.484
# iteration (17350): loss = 1.947, accuracy = 0.500
# iteration (17400): loss = 1.890, accuracy = 0.508
# iteration (17450): loss = 1.814, accuracy = 0.492
# iteration (17500): loss = 2.206, accuracy = 0.445
# Model saved in tf_models/csci-599_proj-17546
# validation for epoch 30
# -  epoch 30: validation accuracy = 0.302
# train for epoch 31
# global step: 17546
# iteration (17550): loss = 1.950, accuracy = 0.500
# iteration (17600): loss = 1.781, accuracy = 0.586
# iteration (17650): loss = 1.705, accuracy = 0.531
# iteration (17700): loss = 1.824, accuracy = 0.602
# iteration (17750): loss = 1.873, accuracy = 0.539
# iteration (17800): loss = 1.808, accuracy = 0.586
# iteration (17850): loss = 1.990, accuracy = 0.469
# iteration (17900): loss = 1.927, accuracy = 0.523
# iteration (17950): loss = 2.019, accuracy = 0.484
# iteration (18000): loss = 1.923, accuracy = 0.500
# iteration (18050): loss = 1.899, accuracy = 0.531
# iteration (18100): loss = 2.023, accuracy = 0.508
# Model saved in tf_models/csci-599_proj-18112
# validation for epoch 31
# -  epoch 31: validation accuracy = 0.304
# train for epoch 32
# global step: 18112
# iteration (18150): loss = 2.050, accuracy = 0.469
# iteration (18200): loss = 1.972, accuracy = 0.422
# iteration (18250): loss = 1.759, accuracy = 0.555
# iteration (18300): loss = 1.737, accuracy = 0.508
# iteration (18350): loss = 1.906, accuracy = 0.484
# iteration (18400): loss = 1.980, accuracy = 0.453
# iteration (18450): loss = 1.647, accuracy = 0.570
# iteration (18500): loss = 1.956, accuracy = 0.453
# iteration (18550): loss = 2.127, accuracy = 0.492
# iteration (18600): loss = 1.876, accuracy = 0.539
# iteration (18650): loss = 2.007, accuracy = 0.484
# Model saved in tf_models/csci-599_proj-18678
# validation for epoch 32
# -  epoch 32: validation accuracy = 0.305
# train for epoch 33
# global step: 18678
# iteration (18700): loss = 1.781, accuracy = 0.531
# iteration (18750): loss = 1.776, accuracy = 0.523
# iteration (18800): loss = 1.849, accuracy = 0.555
# iteration (18850): loss = 1.748, accuracy = 0.539
# iteration (18900): loss = 2.025, accuracy = 0.461
# iteration (18950): loss = 1.792, accuracy = 0.547
# iteration (19000): loss = 1.939, accuracy = 0.539
# iteration (19050): loss = 1.741, accuracy = 0.617
# iteration (19100): loss = 2.088, accuracy = 0.461
# iteration (19150): loss = 1.678, accuracy = 0.562
# iteration (19200): loss = 1.848, accuracy = 0.523
# Model saved in tf_models/csci-599_proj-19244
# validation for epoch 33
# -  epoch 33: validation accuracy = 0.307
# train for epoch 34
# global step: 19244
# iteration (19250): loss = 2.069, accuracy = 0.461
# iteration (19300): loss = 1.718, accuracy = 0.547
# iteration (19350): loss = 2.056, accuracy = 0.516
# iteration (19400): loss = 1.925, accuracy = 0.500
# iteration (19450): loss = 1.617, accuracy = 0.625
# iteration (19500): loss = 1.997, accuracy = 0.484
# iteration (19550): loss = 1.792, accuracy = 0.562
# iteration (19600): loss = 1.836, accuracy = 0.508
# iteration (19650): loss = 1.714, accuracy = 0.523
# iteration (19700): loss = 1.962, accuracy = 0.492
# iteration (19750): loss = 1.855, accuracy = 0.539
# iteration (19800): loss = 1.619, accuracy = 0.586
# Model saved in tf_models/csci-599_proj-19810
# validation for epoch 34
# -  epoch 34: validation accuracy = 0.307
# train for epoch 35
# global step: 19810
# iteration (19850): loss = 1.736, accuracy = 0.578
# iteration (19900): loss = 1.655, accuracy = 0.578
# iteration (19950): loss = 2.073, accuracy = 0.469
# iteration (20000): loss = 1.790, accuracy = 0.578
# iteration (20050): loss = 1.609, accuracy = 0.562
# iteration (20100): loss = 1.878, accuracy = 0.484
# iteration (20150): loss = 1.556, accuracy = 0.625
# iteration (20200): loss = 2.039, accuracy = 0.508
# iteration (20250): loss = 1.901, accuracy = 0.523
# iteration (20300): loss = 1.810, accuracy = 0.555
# iteration (20350): loss = 1.718, accuracy = 0.547
# Model saved in tf_models/csci-599_proj-20376
# validation for epoch 35
# -  epoch 35: validation accuracy = 0.309
# train for epoch 36
# global step: 20376
# iteration (20400): loss = 1.849, accuracy = 0.477
# iteration (20450): loss = 1.709, accuracy = 0.531
# iteration (20500): loss = 1.867, accuracy = 0.531
# iteration (20550): loss = 1.701, accuracy = 0.578
# iteration (20600): loss = 1.865, accuracy = 0.539
# iteration (20650): loss = 1.753, accuracy = 0.547
# iteration (20700): loss = 1.871, accuracy = 0.531
# iteration (20750): loss = 1.626, accuracy = 0.539
# iteration (20800): loss = 1.716, accuracy = 0.562
# iteration (20850): loss = 1.753, accuracy = 0.516
# iteration (20900): loss = 1.813, accuracy = 0.562
# Model saved in tf_models/csci-599_proj-20942
# validation for epoch 36
# -  epoch 36: validation accuracy = 0.310
# train for epoch 37
# global step: 20942
# iteration (20950): loss = 1.834, accuracy = 0.531
# iteration (21000): loss = 1.789, accuracy = 0.508
# iteration (21050): loss = 1.824, accuracy = 0.547
# iteration (21100): loss = 1.647, accuracy = 0.562
# iteration (21150): loss = 1.954, accuracy = 0.492
# iteration (21200): loss = 1.811, accuracy = 0.500
# iteration (21250): loss = 1.832, accuracy = 0.547
# iteration (21300): loss = 1.962, accuracy = 0.500
# iteration (21350): loss = 1.934, accuracy = 0.500
# iteration (21400): loss = 1.669, accuracy = 0.570
# iteration (21450): loss = 1.860, accuracy = 0.508
# iteration (21500): loss = 1.952, accuracy = 0.492
# Model saved in tf_models/csci-599_proj-21508
# validation for epoch 37
# -  epoch 37: validation accuracy = 0.311
# train for epoch 38
# global step: 21508
# iteration (21550): loss = 1.920, accuracy = 0.523
# iteration (21600): loss = 1.878, accuracy = 0.508
# iteration (21650): loss = 1.663, accuracy = 0.562
# iteration (21700): loss = 1.834, accuracy = 0.531
# iteration (21750): loss = 1.799, accuracy = 0.539
# iteration (21800): loss = 1.643, accuracy = 0.594
# iteration (21850): loss = 1.635, accuracy = 0.562
# iteration (21900): loss = 1.713, accuracy = 0.539
# iteration (21950): loss = 1.696, accuracy = 0.617
# iteration (22000): loss = 1.721, accuracy = 0.555
# iteration (22050): loss = 1.622, accuracy = 0.594
# Model saved in tf_models/csci-599_proj-22074
# validation for epoch 38
# -  epoch 38: validation accuracy = 0.312
# train for epoch 39
# global step: 22074
# iteration (22100): loss = 1.744, accuracy = 0.594
# iteration (22150): loss = 1.850, accuracy = 0.547
# iteration (22200): loss = 1.752, accuracy = 0.547
# iteration (22250): loss = 2.044, accuracy = 0.500
# iteration (22300): loss = 1.613, accuracy = 0.523
# iteration (22350): loss = 1.871, accuracy = 0.508
# iteration (22400): loss = 1.561, accuracy = 0.562
# iteration (22450): loss = 1.672, accuracy = 0.578
# iteration (22500): loss = 1.862, accuracy = 0.531
# iteration (22550): loss = 1.746, accuracy = 0.586
# iteration (22600): loss = 1.673, accuracy = 0.555
# Model saved in tf_models/csci-599_proj-22640
# validation for epoch 39
# -  epoch 39: validation accuracy = 0.314
# ***** test accuracy: 0.176
# Done
# 2017-11-10 05:24:35.348507
# Total time: 191.33911037445068 seconds
